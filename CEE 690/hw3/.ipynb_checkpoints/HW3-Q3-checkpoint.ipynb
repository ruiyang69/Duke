# %%
from __future__ import division, print_function, unicode_literals
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

np.random.seed(42)

import matplotlib.pyplot as plt
# %matplotlib inline 
plt.rcParams['axes.labelsize'] = 14
plt.rcParams['xtick.labelsize'] = 12
plt.rcParams['ytick.labelsize'] = 12

from sklearn import model_selection
from sklearn import neighbors
from sklearn import datasets
from sklearn import preprocessing
from sklearn import pipeline
from sklearn import linear_model
from sklearn.metrics import mean_squared_error
from sklearn.metrics import accuracy_score
from sklearn import feature_selection
from sklearn import metrics
from sklearn.datasets import load_iris
from sklearn import cluster
from sklearn import decomposition

# %%
data = load_iris(return_X_y=False)
X = data.data
y = data.target

sse=[]
for k in range(1,20):
    kmeans=cluster.MiniBatchKMeans(n_clusters=k,max_iter=300)
    kmeans.fit(X)
    sse.append(kmeans.inertia_)
fig=plt.figure(figsize=[5,5])
plt.xlabel("number of clusters")
plt.ylabel("SSE")
plt.plot(range(1,20), sse, marker = 'o')
plt.show()

# %%
k_means = cluster.MiniBatchKMeans(n_clusters=3,max_iter=100)
k_means.fit(X)
label_pred = kmeans.labels_

pca = decomposition.PCA(n_components=2)
pca.fit(X)
reduced_X=pca.fit_transform(X)
feature_1=reduced_X[:,0]
feature_2=reduced_X[:,1]
plt.xlabel("data")
plt.ylabel("target")
plt.scatter(feature_1, feature_2, c=label_pred)

# %%
min_sse = min(sse)
cluster = np.array(range(1,20))
best_cluster = cluster[sse.index(min_sse)]
print("the number of clusters I choose is " + str(best_cluster) +", when min_sse = " + str(min_sse))
# Out:
# the number of clusters I choose is 9, when min_sse = 29.211344355925377

# %% [markdown]
# There is a clear division line between the purple parts and the rest. But it is hard to tell the division line between green and yellow ones.

# %%
X = pd.read_csv('hw3_physio.csv')
X=np.array(X.values[:,1:],dtype=np.float64)

see = []
sse=[]
for k in range(1,20):
    kmeans=cluster.MiniBatchKMeans(n_clusters=k,max_iter=300)
    kmeans.fit(X)
    sse.append(kmeans.inertia_)
fig=plt.figure(figsize=[5,5])
plt.xlabel("number of clusters")
plt.ylabel("SSE")
plt.plot(range(1,20), sse, marker = 'o')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-65-7cb64eb3a91d> in <module>
#       5 sse=[]
#       6 for k in range(1,20):
# ----> 7     kmeans=cluster.MiniBatchKMeans(n_clusters=k,max_iter=300)
#       8     kmeans.fit(X)
#       9     sse.append(kmeans.inertia_)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'MiniBatchKMeans'
